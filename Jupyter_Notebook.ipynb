# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Hands-on Lab: Create your Jupyter Notebook

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
# In this notebook, Data Science Tools and Ecosystem are summarized

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
# - Python
# - R
# - SQL
# - Scala
# - Java
# - C++
# - Julia

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include
# - Python :
#   + Pandas - (for data structures).
#   + Numphy - (for arrays & matrices).
#   + matplotlib - (plots & graphs).
#   + Seaborn - (heat maps, time series, violin plots).
#   + scikit-learn - (regression, classification & clustering).
#   + Keras - (deep learning neural networks).
#   + TensorFlow - deep learning (production and deployment).
#   + PyTorch - deep learning (regression and classification).
# - Scala :
#   + Vegas - for statistical data visualizations.
#   + BigDL - for Deep Learning.
# - R :
#   + ggplot2 - for Visualization.
#   + GGally - as an extension of ggplot2.

# %% [markdown]
# | **Data Science Tools**         |
# |--------------------------------|
# | Jupyter IDE                    |
# | RStudio                        |
# | Anaconda Navigator             |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
(3*4)+5
# This a simple arithmetic expression to mutiply then add integers
# Out:
# [1] 17

# %%
#Codeblock made in R
#Minutes declared
minutes <- 200

minutes_to_hours <- function(minutes) {
    #This will convert 200 minutes to hours by diving by 60
    hours <- minutes / 60
    return(hours)
}

#call minutes -> hours function
minutes_to_hours(minutes)
# Out:
# [1] 3.333333

# %% [markdown]
# **Objectives**
#
# * List all tools and assest used on Data Science.
# * Learn and diferenciate between code cells and markdown cells on Jupyter Notebook.
# * Learn arithmetric expresions and how to use them in programming

# %% [markdown]
# ## Autor
#
# Miguel Angel Ortiz del Burgo

# %% [markdown]
# Copyright ©2024 IBM Corporation. All rights reserved.
